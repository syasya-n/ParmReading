# %%
# !pip --no-cache-dir install opencv-python==4.4.0.44

# %%
# 各種インポート
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
parm = cv2.imread('./static/img/2.jpg')

# %%
plt.imshow(parm)

# %%
M = np.float32([[2,0,0],[0,2,0]])
parm_resized = cv2.warpAffine(parm,M,(1500,1500))

# %%
plt.imshow(cv2.cvtColor(parm_resized,cv2.COLOR_BGR2RGB))

# %%
parm_gr = cv2.imread('./static/img/2.jpg',cv2.IMREAD_GRAYSCALE)

# %%
dst = cv2.adaptiveThreshold(parm_gr,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,4)

# %%
def onTrackbar(position):
    global threshold
    threshold = position
cv2.namedWindow("img")
threshold = 100
cv2.createTrackbar("track","img",threshold,255,onTrackbar)
while True:
    dst = cv2.adaptiveThreshold(parm_gr,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,15,threshold)
    cv2.imshow("img",dst)
    if cv2.waitKey(10) == 27:
        break
cv2.destroyAllWindows()

# %%
plt.imshow(dst,cmap="gray")

# %%
dst.shape
# Out:
# (715, 969)

# %%
size = (500,500)

# %%
img_area = cv2.resize(dst,size,interpolation= cv2.INTER_AREA)

# %%
cv2.imshow("area",img_area)
cv2.waitKey(0)
cv2.destroyallwindows()

# %%
print(parm[:,:,2])
# Out:
# [[237 237 237 ... 238 238 238]
#  [237 237 237 ... 238 238 238]
#  [237 237 237 ... 238 238 238]
#  ...
#  [190 190 189 ... 228 228 228]
#  [190 190 189 ... 228 228 228]
#  [190 190 189 ... 228 228 228]]

# %%
rocket_org_height, rocket_org_width, rocket_org_colornum = parm.shape
parm_g = np.zeros((rocket_org_height, rocket_org_width, 3), dtype=np.uint8)
parm_g[:, :, 1] = parm[:, :, 1]

# %%
import cv2
img = cv2.imread('./static/img/2.jpg', cv2.IMREAD_COLOR)
img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
window_name = 'img_hsv'

def onMouse(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:
        crop_img = img[[y], [x]]
        b_val = crop_img.T[0].flatten().mean()
        g_val = crop_img.T[1].flatten().mean()
        r_val = crop_img.T[2].flatten().mean()
        print("R: {}, G: {}, B: {}".format(r_val, g_val, b_val))

cv2.imshow(window_name, img_hsv)
cv2.setMouseCallback(window_name, onMouse)
cv2.waitKey(0)
# Out:
# R: 188.0, G: 164.0, B: 152.0
# R: 207.0, G: 170.0, B: 161.0
# R: 206.0, G: 163.0, B: 156.0
# R: 189.0, G: 156.0, B: 139.0
# R: 205.0, G: 160.0, B: 157.0
# R: 176.0, G: 118.0, B: 104.0
# R: 195.0, G: 159.0, B: 145.0
# R: 177.0, G: 138.0, B: 123.0
# R: 145.0, G: 108.0, B: 90.0
# R: 199.0, G: 154.0, B: 149.0
# R: 164.0, G: 112.0, B: 91.0
# R: 204.0, G: 177.0, B: 166.0
# R: 202.0, G: 175.0, B: 164.0
# R: 198.0, G: 151.0, B: 145.0
# R: 200.0, G: 151.0, B: 146.0
# R: 200.0, G: 151.0, B: 146.0
# R: 236.0, G: 239.0, B: 248.0
# R: 218.0, G: 216.0, B: 227.0
# R: 232.0, G: 241.0, B: 248.0
# R: 182.0, G: 155.0, B: 138.0
# 0

# %%
# 赤のみの画像データの元（rocket_r）を変更しないよう、複製物の作成
parm_g_trimmed = np.copy(parm_g)

# 赤の色について、色の強さ 240 を基準とした二値化
parm_g_wb = parm_g_trimmed[:, :, 2] // 160

# 赤のみの画像データと二値化したデータのかけ算
parm_g_trimmed[:, :, 2] *= parm_g_wb

# 赤の強さ 240 以上のみのピクセルを残した画像データの表示
plt.imshow(cv2.cvtColor(parm_g_trimmed, cv2.COLOR_BGR2RGB))

# %% [markdown]
# im2_edged = cv2.Canny(im2,100,330)
# plt.imshow(im2_edged, cmap="gray")

# %%
# !pip3 freeze
# Out:
# adal==1.2.6
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.10.0
# anaconda-project==0.8.3
# appdirs==1.4.4
# applaunchservices==0.2.1
# appnope @ file:///opt/concourse/worker/volumes/live/0291c9e1-4b15-459f-623e-2770f55be269/volume/appnope_1594338395037/work
# appscript @ file:///opt/concourse/worker/volumes/live/50ca4c96-3090-40bb-6981-3a6114ed0af4/volume/appscript_1594840187551/work
# argh==0.26.2
# argon2-cffi @ file:///opt/concourse/worker/volumes/live/59af29ac-4890-416e-7ab7-794f8d6f7ecd/volume/argon2-cffi_1596828548321/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///opt/concourse/worker/volumes/live/21fd14a9-2a7e-484b-7394-5a9912cdcf80/volume/astroid_1592498459180/work
# astropy==4.0.2
# async-generator==1.10
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1604765588209/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1596578164842/work
# azure-cognitiveservices-vision-face==0.4.1
# ...
